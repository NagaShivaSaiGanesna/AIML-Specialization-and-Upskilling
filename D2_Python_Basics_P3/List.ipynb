# %%
a = [x for x in range(7)]
a
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
a.clear()
a
# Out:
# []

# %%
a = [x for x in range(7)]
a.append(3)

# %%
a
# Out:
# [0, 1, 2, 3, 4, 5, 6, 3]

# %%
b = a
b[0] = -1
print(b)
print(a)
# Out:
# [-1, 1, 2, 3, 4, 5, 6, 3]
# [-1, 1, 2, 3, 4, 5, 6, 3]

# %%
c = a.copy()
c[0] = -3
print(c)
print(a)
# Out:
# [-3, 1, 2, 3, 4, 5, 6, 3]
# [-1, 1, 2, 3, 4, 5, 6, 3]

# %%
print(a.index(3))
# Out:
# 3

# %%
a.insert(0,"Start")
a
# Out:
# ['Start', -1, 1, 2, 3, 4, 5, 6, 3]

# %%
c.pop()
c.pop(-3)
c
# Out:
# [-3, 1, 2, 3, 5, 6]

# %%
c.sort(reverse=True)
c
# Out:
# [6, 5, 3, 2, 1, -3]
