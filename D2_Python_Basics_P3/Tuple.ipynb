# %%
a = ()
print(type(a))
# Out:
# <class 'tuple'>

# %%
a.count(2)
# Out:
# 0

# %%
a.index(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a.index(2)
#
# ValueError: tuple.index(x): x not in tuple

# %%
x = list(a)
x.extend([x for x in range(3)])
a = tuple(x.copy())

# %%
a
# Out:
# (0, 1, 2)

# %%
x = (2)
print(type(x))
# Out:
# <class 'int'>

# %%
x = (2,)
print(type(x))
# Out:
# <class 'tuple'>
