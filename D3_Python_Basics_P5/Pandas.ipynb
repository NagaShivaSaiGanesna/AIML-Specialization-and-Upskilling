# %%
import pandas as pd

# %%
x = [1,2,4,5,7,84,3,5]
y = [0,1,3,4,5,7,8,3]
df = pd.Series(x,index = y)
df
# Out:
# 0     1
# 1     2
# 3     4
# 4     5
# 5     7
# 7    84
# 8     3
# 3     5
# dtype: int64

# %%
x = [1,2,4,5,7,84,3,5]
y = [0,1,3,4,5,7,8,3]
df = pd.DataFrame(x,index = y)
df
# Out:
#     0
# 0   1
# 1   2
# 3   4
# 4   5
# 5   7
# 7  84
# 8   3
# 3   5

# %%
x = {1:2,2:3,4:5,5:6}
df = pd.Series(x)
df
# Out:
# 1    2
# 2    3
# 4    5
# 5    6
# dtype: int64

# %%
x = {'a':2,'b':3,'c':5,'d':6}
df = pd.DataFrame(x)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 x = {'a':2,'b':3,'c':5,'d':6}
# ----> 2 df = pd.DataFrame(x)
#       3 df
#
# File c:\Users\ShivaGanesna\Downloads\IGTMUAD\.venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# ...

# %%
x = {
    'a' : [1,2,3,4,5],
    'b' : [2,354,631,11,3]
}
df = pd.Series(x)
df
# Out:
# a         [1, 2, 3, 4, 5]
# b    [2, 354, 631, 11, 3]
# dtype: object

# %%
x = {
    'a' : [1,2,3,4,5],
    'b' : [2,354,631,11,3]
}
df = pd.DataFrame(x)
df
# Out:
#    a    b
# 0  1    2
# 1  2  354
# 2  3  631
# 3  4   11
# 4  5    3

# %%
x = [
    {'a' : [1,2,3,4,5]},
    {'b' : [2,354,631,11,3]}
]
df = pd.DataFrame(x)
df
# Out:
#                  a                     b
# 0  [1, 2, 3, 4, 5]                   NaN
# 1              NaN  [2, 354, 631, 11, 3]

# %%
df.loc[0]
# Out:
# a    1
# b    2
# Name: 0, dtype: int64

# %%
df.iloc[0]
# Out:
# a    1
# b    2
# Name: 0, dtype: int64

# %%
df.at[0,'a']
# Out:
# np.int64(1)

# %%
df.describe()
# Out:
#               a           b
# count  5.000000    5.000000
# mean   3.000000  200.200000
# std    1.581139  284.258157
# min    1.000000    2.000000
# 25%    2.000000    3.000000
# 50%    3.000000   11.000000
# 75%    4.000000  354.000000
# max    5.000000  631.000000
