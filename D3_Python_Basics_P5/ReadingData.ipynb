# %%
import pandas as pd
from io import StringIO

json_data = '''
[
    {"id": 1, "name": "James", "details": {"dept": "IT", "salary": 7000}},
    {"id": 2, "name": "Anna", "details": {"dept": "HR", "salary": 5000}}
]
'''
df_json = pd.read_json(StringIO(json_data))
print(df_json)
# Out:
#    id   name                         details
# 0   1  James  {'dept': 'IT', 'salary': 7000}
# 1   2   Anna  {'dept': 'HR', 'salary': 5000}

# %%
df_json.iloc[0]['details']['salary']
# Out:
# 7000
