# %%
s = "hellowdgcew"

# %%
print(s[0:7:-1])

# %%
tpl_dict = {
    (1, 2): 3,
    (4, 5): 6,
    (7, 8): 9,
    "a" : -1
}
c = (1,2)
print(tpl_dict)
print(tpl_dict[c])
print(tpl_dict["a"])
# Out:
# {(1, 2): 3, (4, 5): 6, (7, 8): 9, 'a': -1}
# 3
# -1

# %%
s = {1, 2, 2, 3, 4, 4, 5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
fs = frozenset(range(1, 6))
print(fs)
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
d = {'''a''':1}
print(d)
# Out:
# {'a': 1}

# %%
d1 = {i: i for i in range(1, 11)}
d2 = {i: i**2 for i in range(1, 11)}
d1.update(d2)
print(d1)
print(d2)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
def show(s: str) -> int:
    '''
    This function prints the input value
    '''
    print(s)
    return 1

show("Hello")
# Out:
# Hello
# 1

# %%
def greet(name="Guest"):
    print(f"Hello {name} Welcome To the paradise")

greet()
# Out:
# Hello Guest Welcome To the paradise

# %%
import time

def timer_decorator(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"Function {func.__name__} took {end_time - start_time} seconds to execute.")
        return result
    return wrapper

@timer_decorator
def complex_calculation(n):
    return sum(x**2 for x in range(n))

# Test
print(complex_calculation(10000))
# Out:
# Function complex_calculation took 0.0012273788452148438 seconds to execute.
# 333283335000
