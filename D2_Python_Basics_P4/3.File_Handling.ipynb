# %%
import os
curr_path = os.getcwd()
print(curr_path)
# Out:
# c:\Users\ShivaGanesna\Downloads\IGTMUAD\D1_Python_Basics_P4

# %%
with open ("Example.txt","r") as file:
    print(file.read())
# Out:
# Hi Hello
# Hi Hello
# Hi Hello

# %%
with open ("Example.txt","a") as file:
    print(file.write("Heyy"))
# Out:
# 4

# %%
with open ("Example.txt","w") as file:
    print(file.write("Heyy"))
# Out:
# 4

# %%
with open ("Example.txt","r") as file:
    for line in file.readlines():
        print(line,end = "")
# Out:
# deiufvhkv
# vDSsFD;LVCMSDVKMF
# ZSDJVNDLKZFV
# ZSDJVNFDLKVIF ,F
# DF NLJZNDFOIVRV,FDZ
# DSNVJneaFDB;LVS,   adlmv;kdm d kl KAEDKF wd s
#  sd lksdlk mfld fd mkfd m fsdnsd  dsm fd djs deiufvhkvs n
#
#  ws SD ljsn;kfd ;kNFS
#
#   VFDVMFDZNVLJFD V' dKA
#   FDZ
#   NDF LVCMSDVKMF
#
#    'LDM
#    ;FDZVMKFDMV;KGD
#    '
#    D
#    FD MKF
#    DM 'K

# %%
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
### Binary Files

# Writing to a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)
# Reading a binary file
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### Writing and then reading a file

with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning
    file.seek(0)

    ## Read the content of the file
    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line

# %%
with open ("Example.txt",'r') as f:
    words,characters = 0,0
    for line in f.readlines():
        print(line.split(" "))
        words = words + len(line.split(" "))
        characters = characters + len(line)
    print(words,characters)
# Out:
# ['Hello', 'world\n']
# ['This', 'is', 'a', 'new', 'line']
# 7 30
